# %% [markdown]
# <a href="https://colab.research.google.com/github/caganze/tutorials/blob/main/Introduction_to_Random_Forests_and_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install astroquery
# !pip install astroquery
# Out:
# Collecting astroquery
#   Downloading astroquery-0.4.4-py3-none-any.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 13.2 MB/s
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.7/dist-packages (from astroquery) (1.0.1)
# Collecting keyring>=4.0
#   Downloading keyring-23.4.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: astropy>=4.0 in /usr/local/lib/python3.7/dist-packages (from astroquery) (4.3.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from astroquery) (1.19.5)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from astroquery) (4.6.3)
# Requirement already satisfied: requests>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from astroquery) (2.23.0)
# Collecting pyvo>=1.1
#   Downloading pyvo-1.2-py3-none-any.whl (832 kB)
#      |████████████████████████████████| 832 kB 61.9 MB/s
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0->astroquery) (2.0.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0->astroquery) (4.8.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from html5lib>=0.999->astroquery) (1.15.0)
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=4.0->astroquery) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=4.0->astroquery) (3.10.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.4.3->astroquery) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.4.3->astroquery) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.4.3->astroquery) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.4.3->astroquery) (2021.10.8)
# Collecting cryptography>=2.0
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 57.9 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=4.0->astroquery) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=4.0->astroquery) (2.21)
# Installing collected packages: jeepney, cryptography, SecretStorage, pyvo, keyring, astroquery
# Successfully installed SecretStorage-3.3.1 astroquery-0.4.4 cryptography-36.0.1 jeepney-0.7.1 keyring-23.4.0 pyvo-1.2

# %%
from astroquery.sdss import SDSS  # enables direct queries to the SDSS database
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import pandas as pd
import warnings
from tqdm import tqdm
warnings.filterwarnings("ignore")

# %%
#plotting aesthetics
import matplotlib as mpl
import seaborn as sns
plt.style.use('fivethirtyeight')
mpl.rcParams['grid.color'] = 'k'
mpl.rcParams['grid.linestyle'] = '--'
mpl.rcParams['grid.linewidth'] = 0.5
mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['figure.figsize'] = [8.0, 4.0]
mpl.rcParams['figure.dpi'] = 80
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['font.size'] = 18
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'large'
mpl.rcParams['xtick.bottom']=True
mpl.rcParams['xtick.top']=True
mpl.rcParams['xtick.major.width']=0.9
mpl.rcParams['xtick.minor.width']=0.9
mpl.rcParams['ytick.major.width']=0.9
mpl.rcParams['ytick.minor.width']=0.9
mpl.rcParams['ytick.right']=True
mpl.rcParams['ytick.left']=True
mpl.rcParams['xtick.direction']='in'
mpl.rcParams['ytick.direction']='in'

mpl.rc('xtick', labelsize=14) 
mpl.rc('ytick', labelsize=14) 
font = {'family' : 'Helvetica',
        'size'   : 14}
mpl.rc('font', **font)
mpl.rc('text', usetex=False)
mpl.rcParams['agg.path.chunksize'] = 10000

# %% [markdown]
# Author: Christian Aganze
#
#
# Let's select magnitud measurements for 10000 stars and galaxies from SDSS.
#
# ** Note** - the SDSS database contains duplicate observations, flagged observations, and non-detections, which we condition the query to exclude (as explained further below). We also exclude quasars, as the precise photometric classification of these objects is ambiguous: low-$z$ AGN have resolvable host galaxies, while high-$z$ QSOs are point-sources. Query conditions:
#
# * p.mode = 1 select only the primary photometric detection of a source
#
# * s.sciencePrimary = 1 select only the primary spectroscopic detection of a source (together with above, prevents duplicates)
#
# * p.clean = 1 the SDSS clean flag excludes flagged observations and sources with non-detections
#
# * s.class != 'QSO' removes potentially ambiguous QSOs from the training set

# %%
#query a 10000 objects 
TSquery = """SELECT TOP 10000 
             p.psfMag_r, p.fiberMag_r, p.fiber2Mag_r, p.petroMag_r, 
             p.deVMag_r, p.expMag_r, p.modelMag_r, p.cModelMag_r, 
             s.class
             FROM PhotoObjAll AS p JOIN specObjAll s ON s.bestobjid = p.objid
             WHERE p.mode = 1 AND s.sciencePrimary = 1 AND p.clean = 1 AND s.class != 'QSO'
             ORDER BY p.objid ASC
               """
SDSSts = SDSS.query_sql(TSquery).to_pandas()
SDSSts.head(5)
# Out:
#    psfMag_r  fiberMag_r  fiber2Mag_r  ...  modelMag_r  cModelMag_r      class
# 0  18.50914    18.65870     19.34104  ...    17.58728     17.49310  b'GALAXY'
# 1  19.03946    19.33727     19.82178  ...    19.04397     19.04397    b'STAR'
# 2  19.89376    19.79181     20.47909  ...    19.36779     19.25845  b'GALAXY'
# 3  22.04833    22.07411     22.69651  ...    21.33033     21.33033  b'GALAXY'
# 4  21.57319    21.57904     22.22763  ...    20.40414     20.20997  b'GALAXY'
#
# [5 rows x 9 columns]

# %%
#quick visualization of the data 
fig, ax=plt.subplots(figsize=(6, 4))
sns.scatterplot(x="psfMag_r", y="modelMag_r",
            hue="class", palette=["#FF4136", "#0074D9"], style="class",
            data=SDSSts, ax=ax)
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Random Forest Classifier Example

# %% [markdown]
# Let's do some reformatting of the data to allow numerical spectral types \

# %%
#some reformatting 
#let's use numerical labels
def numerical_class(c):
  if c==b'GALAXY':
    return 0
  elif c==b'STAR':
    return 1
  else:
    return -1
SDSSts['num_class']=SDSSts['class'].apply(numerical_class)

# %%
SDSSts.head(5)
# Out:
#    psfMag_r  fiberMag_r  fiber2Mag_r  ...  cModelMag_r      class  num_class
# 0  18.50914    18.65870     19.34104  ...     17.49310  b'GALAXY'          0
# 1  19.03946    19.33727     19.82178  ...     19.04397    b'STAR'          1
# 2  19.89376    19.79181     20.47909  ...     19.25845  b'GALAXY'          0
# 3  22.04833    22.07411     22.69651  ...     21.33033  b'GALAXY'          0
# 4  21.57319    21.57904     22.22763  ...     20.20997  b'GALAXY'          0
#
# [5 rows x 10 columns]

# %%
len(SDSSts[SDSSts['num_class']==0]), len(SDSSts[SDSSts['num_class']==1])
# Out:
# (4656, 5344)

# %% [markdown]
# Let's split the data into a a training, validation and test set
#
# This is a critical step in a setting up our machine learning model.
#
# Splitting the data into smaller these sets allows us to fit the model and evaluate how our machine learning model would perform on unseen/new data. ` sklearn ` has all these tools built in for us, we can just call them directly

# %%
from sklearn.model_selection import train_test_split
RSEED = 42  

#remove 
feats = list(SDSSts.columns)
feats.remove('class')
feats.remove('num_class')

X0 = np.array(SDSSts[feats]) #data
y0 = np.array(SDSSts['num_class']) #labels 

X, X_test, y, y_test = train_test_split(X0,y0,train_size=0.85, random_state=RSEED, shuffle=True)
X_train, X_val, y_train, y_val = train_test_split(X,y, random_state=RSEED, train_size=0.9, shuffle=True)

# %%
len(X_train), len(X_val), len(X_test)
# Out:
# (7650, 850, 1500)

# %%
y_train, X_train
# Out:
# (array([1, 0, 0, ..., 1, 1, 1]),
#  array([[17.80506, 18.16448, 18.64858, ..., 17.82479, 17.8247 , 17.8247 ],
#         [19.65141, 19.55112, 20.25477, ..., 18.00459, 17.53884, 17.76034],
#         [18.35198, 18.1651 , 18.81612, ..., 17.10813, 16.68579, 16.68579],
#         ...,
#         [20.31348, 20.66008, 21.14258, ..., 20.28644, 20.28644, 20.28644],
#         [17.72037, 18.06293, 18.55004, ..., 17.70456, 17.70224, 17.70224],
#         [20.1088 , 20.42461, 20.92325, ..., 20.10264, 20.10322, 20.10319]]))

# %% [markdown]
# Let's now build a random forest classifier model directly from Sklearn

# %%
#let's build a random forest classifier 
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score

RF = RandomForestClassifier(n_estimators =50)
RF.fit(X_train, y_train) #fitting to the training set 
test_preds = RF.predict(X_test) #predict on the test 

print("The raw features produce a model with accuracy ~{:.4f} !".format(accuracy_score(y_test, test_preds)))
# Out:
# The raw features produce a model with accuracy ~0.9740 !

# %% [markdown]
# One can find out which magnitudes here are more important in distinguishing beteen stars and galaxies

# %%
RF.feature_importances_
# Out:
# array([0.27988739, 0.11538007, 0.17321585, 0.09494723, 0.09732469,
#        0.0601711 , 0.09099713, 0.08807653])

# %%
fig, ax=plt.subplots()

tree_feature_importances = (
    RF.feature_importances_)
    
sorted_idx = tree_feature_importances.argsort()

x_ticks = np.arange(0, len(feats))
ax.bar(x_ticks, tree_feature_importances[sorted_idx])
ax.set_xticklabels(np.array(feats)[sorted_idx], rotation='vertical')
ax.set_xticks(x_ticks)
ax.set_title("Random Forest Feature Importance ")
# Out:
# Text(0.5, 1.0, 'Random Forest Feature Importance ')
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# The most important magnitude alone cannot distinguish beteen stars and galaxies since their distributions (stars vs galaxies) overlap

# %%
#let's look at the distribution of the most important feature
fig, ax=plt.subplots()
h=plt.hist(SDSSts.psfMag_r[SDSSts.num_class==0], bins='auto',\
           histtype='step', label='GALAXY', lw=3)
h=plt.hist(SDSSts.psfMag_r[SDSSts.num_class==1], bins='auto', \
           histtype='step', label='STAR', lw=3 )
ax.set(xlabel='PSF Mag r', ylabel='Number ')
ax.legend(loc='upper left')
#sure these to

# %% [markdown]
# *How does this model perform in predicting labels for high redshift QSOs?*
#
# Let's select some QSOs to find out,for the purpose of this exericse we are  assuming them to be "like stars" they'd look close to point-sources in images

# %%
QSOquery = """SELECT TOP 10000 
             p.psfMag_r, p.fiberMag_r, p.fiber2Mag_r, p.petroMag_r, 
             p.deVMag_r, p.expMag_r, p.modelMag_r, p.cModelMag_r, 
             s.class
             FROM PhotoObjAll AS p JOIN specObjAll s ON s.bestobjid = p.objid
             WHERE p.mode = 1 AND s.sciencePrimary = 1 AND p.clean = 1 AND s.class = 'QSO'
             AND s.z > 1.5
             ORDER BY s.specobjid ASC
               """
QSOts = SDSS.query_sql(QSOquery).to_pandas()

qso_X = np.array(QSOts[feats])
qso_y = np.ones(len(QSOts))    # we are defining QSOs as stars for this exercise 

qso_preds = RF.predict(qso_X)

print("The RF model correctly classifies ~{:.4f} of the QSOs".format(accuracy_score(qso_y, qso_preds)))
# Out:
# The RF model correctly classifies ~0.9873 of the QSOs

# %%
(qso_y==1).all()
# Out:
# True

# %% [markdown]
# Our random forest model can distinguish between stars and galaxies and can classify QSOs as stars at a 98% accuracy !

# %% [markdown]
# # Linear Regression
#
# *Can we predict spectral types of stars from their colors alone?*
#
# Linear regression is fitting data to a line defined by
#
# $$ y = m x+ b $$
#
# For the second part of this exercise, let's move away from SDSS data of galaxies and focus on M dwarfs. Luckily, C. Theissen has collected a dataset of optically classified M dwarfs and their colors in SDSS. Let's compare how a machine learning model will perform vs linear regression.
#
# For the rest of the notebook, we will be using an "error rate" defined as
#
# $$ \text{error} = \text{average}( | y- \hat{y}|) $$
#
# where y is the true spectral type and predicted spectral type

# %%
import pandas as pd
#read some data (should be a small file)
# !wget -O mls_gaia_sdss.csv https://www.dropbox.com/s/wluakj8jxhumlpf/ctheissen_sdss_gaia.csv?dl=0
mls_gaia_sdss=pd.read_csv('mls_gaia_sdss.csv')
# Out:
# --2021-12-20 17:30:27--  https://www.dropbox.com/s/wluakj8jxhumlpf/ctheissen_sdss_gaia.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/wluakj8jxhumlpf/ctheissen_sdss_gaia.csv [following]
# --2021-12-20 17:30:27--  https://www.dropbox.com/s/raw/wluakj8jxhumlpf/ctheissen_sdss_gaia.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca2962091393fc07ccce5a3fd63.dl.dropboxusercontent.com/cd/0/inline/BcOIji5nMdG1HBsOTNIXAZrUY8pKCu3NukxAAUBKBX64qzAE6zpWp3f4BoTwCsdmB4PjTuAm_gzN_GRARyvE1c0-iLjfEWKYygIsJj1jRWwsAvJm4Mq6iAaGoo32e1tv_nKcbQRk86AhLxrwmAm0b1Mm/file# [following]
# --2021-12-20 17:30:28--  https://uca2962091393fc07ccce5a3fd63.dl.dropboxusercontent.com/cd/0/inline/BcOIji5nMdG1HBsOTNIXAZrUY8pKCu3NukxAAUBKBX64qzAE6zpWp3f4BoTwCsdmB4PjTuAm_gzN_GRARyvE1c0-iLjfEWKYygIsJj1jRWwsAvJm4Mq6iAaGoo32e1tv_nKcbQRk86AhLxrwmAm0b1Mm/file
# Resolving uca2962091393fc07ccce5a3fd63.dl.dropboxusercontent.com (uca2962091393fc07ccce5a3fd63.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6027:15::a27d:480f
# Connecting to uca2962091393fc07ccce5a3fd63.dl.dropboxusercontent.com (uca2962091393fc07ccce5a3fd63.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98061 (96K) [text/plain]
# Saving to: ‘mls_gaia_sdss.csv’
#
# mls_gaia_sdss.csv   100%[===================>]  95.76K   397KB/s    in 0.2s
#
# 2021-12-20 17:30:28 (397 KB/s) - ‘mls_gaia_sdss.csv’ saved [98061/98061]

# %%
mls_gaia_sdss.head(5)
# Out:
#    Unnamed: 0                objid  psfmag_u  ...  psfMagErr_z  class  subclass
# 0           0  1237646587712701184  24.84781  ...     0.028421   STAR        L4
# 1           1  1237646587713619456  24.21348  ...     0.030397   STAR        M3
# 2           2  1237646646230975488  24.88639  ...     0.023530   STAR        M3
# 3           3  1237648702966530304  23.19713  ...     0.014825   STAR        M1
# 4           4  1237648702966530304  23.19713  ...     0.014825   STAR        M1
#
# [5 rows x 14 columns]

# %% [markdown]
# Let's create a numerical type

# %%
def type_to_num(st):
  offset=10
  zero_le=st[0]
  if st.startswith('L'):
    offset=20
  if st.startswith('T'):
    offset=30
  return offset+float(st.split(zero_le)[1])

# %%
mls_gaia_sdss['num_type']=mls_gaia_sdss.subclass.apply(type_to_num)
#for the purpose of this exercise let's limit ourselves to M stars
mls_gaia_sdss=mls_gaia_sdss[mls_gaia_sdss.num_type < 20 ]

# %%
mls_gaia_sdss.head(5)
# Out:
#    Unnamed: 0                objid  psfmag_u  ...  class  subclass  num_type
# 1           1  1237646587713619456  24.21348  ...   STAR        M3      13.0
# 2           2  1237646646230975488  24.88639  ...   STAR        M3      13.0
# 3           3  1237648702966530304  23.19713  ...   STAR        M1      11.0
# 4           4  1237648702966530304  23.19713  ...   STAR        M1      11.0
# 5           5  1237648702966530304  23.19713  ...   STAR        M3      13.0
#
# [5 rows x 15 columns]

# %% [markdown]
# Let's compute some color combinations and plot them against spectral type

# %%
mls_gaia_sdss['r-i']=mls_gaia_sdss.psfmag_r-mls_gaia_sdss.psfmag_i
mls_gaia_sdss['i-z']=mls_gaia_sdss.psfmag_i-mls_gaia_sdss.psfmag_z
mls_gaia_sdss['g-z']=mls_gaia_sdss.psfmag_g-mls_gaia_sdss.psfmag_z
mls_gaia_sdss['u-z']=mls_gaia_sdss.psfmag_u-mls_gaia_sdss.psfmag_z
mls_gaia_sdss['r-z']=mls_gaia_sdss.psfmag_r-mls_gaia_sdss.psfmag_z
mls_gaia_sdss['g-r']=mls_gaia_sdss.psfmag_g-mls_gaia_sdss.psfmag_r
mls_gaia_sdss['g-i']=mls_gaia_sdss.psfmag_g-mls_gaia_sdss.psfmag_i
mls_gaia_sdss['r-u']=mls_gaia_sdss.psfmag_r-mls_gaia_sdss.psfmag_u

# %%
#color spectral type relation
fig, ax=plt.subplots()
ax.errorbar(mls_gaia_sdss['r-i'], \
            mls_gaia_sdss.num_type, fmt='o', alpha=0.3)
ax.set(xlabel='r-i', ylabel='Spectral Type', xlim=[0., 3])
ax.invert_yaxis()

# %% [markdown]
# we could fit a line to the data since there seems to be a linear relationship between the colors and spectral types
#
# Let's ignore the uncertainties in the data for now
#
# For this part, we will use the `scipy` library which has this method built in for us. Fill free to code your own linear regression code.

# %%
from scipy import  stats
slope, intercept, _, _, _ = stats.linregress(mls_gaia_sdss['r-i'].values, \
                                       mls_gaia_sdss.num_type.values)

# %%
slope, intercept
# Out:
# (2.0752976383492157, 10.208595759485636)

# %%
#color spectral type relation
fig, ax=plt.subplots()
ax.errorbar(mls_gaia_sdss['r-i'].values, \
            mls_gaia_sdss.num_type, fmt='o', alpha=0.3)

#let's oveplot a line 
xgrid=np.linspace(0, 3, 20)
ax.plot(xgrid, slope*xgrid+intercept, c='k')
ax.set(xlabel='r-i', ylabel='Spectral Type', xlim=[0., 3])
ax.invert_yaxis()

# %%
#compute an average error rate
line_preds=slope*mls_gaia_sdss['r-i'].values+intercept
print ('average error rate {:.4f} subtypes'.format(np.nanmean(abs(line_preds-mls_gaia_sdss.num_type))))
# Out:
# average error rate 1.2777 subtypes

# %% [markdown]
# Not too bad for a line!

# %% [markdown]
# # Random Forest Regressor

# %% [markdown]
# Now we're going to fit a random forest regressor to the r-i colors vs spectral type and compare the results.
#
# For this part of the exercise, we will use `RandomForestRegressor` from `sklearn`

# %%
X0=mls_gaia_sdss['r-i'].values.reshape(-1, 1)
y0=mls_gaia_sdss.num_type.values

# %%
X, X_test, y, y_test = train_test_split(X0,y0,train_size=0.85, random_state=RSEED, shuffle=True)
X_train, X_val, y_train, y_val = train_test_split(X,y, random_state=RSEED, train_size=0.9, shuffle=True)

# %%
RF_reg = RandomForestRegressor(n_estimators = 50)
RF_reg.fit(X_train, y_train)
test_preds = RF_reg.predict(X_test)
print ('average error rate for the RF is {:.4f} subtypes'.format(np.nanmean(abs(test_preds-y_test))))
#this is orse slightly better than the line fit
# Out:
# average error rate for the RF is 1.1455 subtypes

# %% [markdown]
# We can also visualize the predictions of on the test set
#
# Unlike the line fit, there is no "analytical" expression to obtain the prediction

# %%
fig, ax=plt.subplots()
ax.errorbar(X_test.flatten(), \
            y_test, fmt='o', alpha=0.3, label='Data')

#let's oveplot RF predictions
ax.errorbar(X_test.flatten(), \
            test_preds, fmt='^', alpha=0.3, label='RF predictions')
ax.set(xlabel='r-i', ylabel='Spectral Type', xlim=[0., 3])
ax.invert_yaxis()
ax.legend()

# %% [markdown]
# Challenge: Increase the number of trees (estimators) and compute your error rate

# %% [markdown]
#  *what if we used more color-combinations ?*

# %%
X0=mls_gaia_sdss[['r-i', 'i-z', 'g-z', 'u-z', 'r-z', 'g-r', 'g-i', 'r-u']].values
y0=mls_gaia_sdss.num_type.values

X, X_test, y, y_test = train_test_split(X0,y0,train_size=0.85, random_state=RSEED, shuffle=True)
X_train, X_val, y_train, y_val = train_test_split(X,y, random_state=RSEED, train_size=0.9, shuffle=True)

# %%
RF_reg_more = RandomForestRegressor(n_estimators = 50)
RF_reg_more.fit(X_train, y_train)
test_preds = RF_reg_more.predict(X_test)
print ('average error rate for the RF is {:.4f} subtypes'.format(np.nanmean(abs(test_preds-y_test))))
#this is didn't improve, discuss
# Out:
# average error rate for the RF is 1.1799 subtypes

# %%
fig, ax=plt.subplots()
ax.errorbar(X_test[:,0], \
            y_test, fmt='o', alpha=0.3, label='Data')

#let's oveplot RF predictions
ax.errorbar(X_test[:,0], \
            test_preds, fmt='^', alpha=0.3, label='RF predictions')
ax.set(xlabel='r-i', ylabel='Spectral Type', xlim=[0., 3])
ax.invert_yaxis()
ax.legend()
#is this an improvement?

# %% [markdown]
# *Is this an improvement?*

# %% [markdown]
# # Evaluating model & Optimizing Parameters: K-fold Cross- Validation and Grid Search

# %% [markdown]
# Let's use the idea of cross-validation to evaluate the performance of this  model on a new dataset

# %%
#manual k-fold cross validation
from numpy import array
from sklearn.model_selection import KFold

# %%
def cross_validate(data, labels, k=3):
  """
  This function takes in a model and performs k-fold cross validation 
  Returns the average error rate 
  """
  error=[]
  model= RandomForestRegressor(n_estimators = 50)
  #split the data into 
  kfold = KFold(k, shuffle=True, random_state=RSEED)
  for train_idx, test_idx in tqdm(kfold.split(data)): 
    #train & predict
    model.fit(data[train_idx], labels[train_idx])
    test_preds = model.predict(data[test_idx])
    error.append( np.nanmean(abs(test_preds-labels[test_idx])))

  print( ' Average Model Error  {:.4f} after {} iterations!'.format(np.nanmean(error), k))

# %%
cross_validate( X_train, y_train, k=5)
#ok this is the best we can do
# Out:
# 5it [00:01,  3.91it/s]
#  Average Model Error  1.0703 after 5 iterations!

# %% [markdown]
# Let's perform a random search over the number of trees using sklearn functions

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
def error_rate(y, ypred):
  return np.nanmean(abs(y-ypred))

# %% [markdown]
# Reformat our error function to be digestible by sklearn

# %%
from sklearn.metrics import make_scorer
my_scorer = make_scorer(error_rate, greater_is_better=False)

# %%
def perform_random_search(X_train, y_train):
  """
  This function perfoms a search over an set of models using cross-validation

  The best function is defined to have the smallest error rate
  """
  #default is 5-fold CV but can be modified
  param_dist = {'n_estimators': np.linspace(20, 500, 10, dtype=int)}            
  random_search = RandomizedSearchCV( RandomForestRegressor(), param_distributions=param_dist, n_jobs=-1, 
                                     verbose=True, random_state=RSEED, scoring=my_scorer )
  random_search.fit(X_train, y_train)
  print ('our best model has {} estimators'.format( random_search.best_estimator_.n_estimators))
  return random_search.best_estimator_

# %%
#evaluate our best model
best_model=perform_random_search(X_train, y_train)
best_model.fit(X_train, y_train)
test_preds = best_model.predict(X_test)
print ('average error rate for the RF is {:.4f} subtypes'.format(np.nanmean(abs(test_preds-y_test))))
#discuss the results
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# our best model has 20 estimators
# average error rate for the RF is 1.1336 subtypes

# %% [markdown]
# Challenge problem: replace  RandomizedSearchCV by GridSearchCV, compare results

# %%
features=np.array(['r-i', 'i-z', 'g-z', 'u-z', 'r-z', 'g-r', 'g-i', 'r-u'])

# %%
#let's visualize other color-color spaces 
fig, ax=plt.subplots(ncols=2, nrows=4, figsize=(10, 14))
for idx, a in enumerate(np.concatenate(ax)):
  a.errorbar(X_test[:,idx], \
              y_test, fmt='o', alpha=0.3, label='Data')

  #let's oveplot RF predictions
  a.errorbar(X_test[:,idx], \
              test_preds, fmt='^', alpha=0.3, label='RF predictions')
  a.set(xlabel=features[idx], ylabel='Spectral Type')
  a.invert_yaxis()
  a.legend(fontsize=(10))
  plt.tight_layout()
  #is this an improvement?
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %%
#feature importance, which color best classifies M dwarfs?
fig, ax=plt.subplots()
tree_feature_importances = (
    best_model.feature_importances_)
    
sorted_idx = tree_feature_importances.argsort()

x_ticks = np.arange(0, len(features))
ax.bar(x_ticks, tree_feature_importances[sorted_idx])
ax.set_xticklabels(np.array(features)[sorted_idx], rotation='vertical')
ax.set_xticks(x_ticks)
ax.set_title("Random Forest Regressor Feature Importance ")
# Out:
# Text(0.5, 1.0, 'Random Forest Regressor Feature Importance ')

# %% [markdown]
# # Challenge problem: logistic regression

# %% [markdown]
# Challenge, model the spectral type ($y$) given a matrix of colors ($\vec{x}$) as
#
# $$ y = \sigma (\vec{w} \cdot \vec{x}) $$
#
# and $\vec{w}$  is a weight function which is a parameter to be determined (just like the slope and intercept in the linear regression problem)
#
#  $\sigma$ is a sigmoid function defined as
#
# $$\sigma (z) = \frac{1}{1+ \exp({-z})}$$
#
# This is an "activation function" used in NN nets
#
# Compute the average error rate, how does this compare to the RF and linear regression result ?
#
# You can compute the gradient as
#
# $$
# \frac{\partial{L}}{\partial{w_\alpha}} =  \sum _{t} x_{\alpha, t} \biggl( y_t-  \sigma (\vec{w} \cdot \vec{x_t}) \biggl)
# $$
#
# Implement the gradient descent algorithm

# %% [markdown]
# # Simple Neural Network
#
# Compare results to a 5-layer fully-connected neural network
#
# In this part of the tutorial, we're going to use the keras libray

# %%
#import the keras library
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
import tensorflow.keras.metrics as k_metrics

# %%
#build a simple model
units = 64 #64 nodes of each
learning_rate = 1e-5 #learning rate of 10**-4, try changing it around

heurmodel = keras.Sequential() #this class helps add layers sequentially
heurmodel.add(keras.layers.Activation('sigmoid')) #let's use a sigmoid "activation function for the input"

#add deep layers in sequence
for i in range(1, 6):
  layer=keras.layers.Dense(units=units, activation='sigmoid', input_dim=X.shape[1], use_bias=True, 
                kernel_initializer='GlorotUniform')
  heurmodel.add(layer)
  
#the final prediction should be one
heurmodel.add(Dense(1,activation="linear"))

heurmodel.compile(loss='mean_absolute_error' ,optimizer = keras.optimizers.Adam(learning_rate =learning_rate))

#fit 
model_history= heurmodel.fit(x=X_train, y=y_train,  epochs=4000, 
              shuffle=True, validation_split=0.25, verbose=1, batch_size=70)
# Out:
# Streaming output truncated to the last 5000 lines.
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0981 - val_loss: 3.0669
# Epoch 1502/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0950 - val_loss: 3.0638
# Epoch 1503/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0919 - val_loss: 3.0607
# Epoch 1504/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0889 - val_loss: 3.0576
# Epoch 1505/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0858 - val_loss: 3.0545
# Epoch 1506/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0827 - val_loss: 3.0514
# Epoch 1507/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0796 - val_loss: 3.0483
# Epoch 1508/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0765 - val_loss: 3.0452
# Epoch 1509/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0734 - val_loss: 3.0421
# Epoch 1510/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0703 - val_loss: 3.0390
# Epoch 1511/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0672 - val_loss: 3.0359
# Epoch 1512/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0641 - val_loss: 3.0328
# Epoch 1513/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0610 - val_loss: 3.0298
# Epoch 1514/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0579 - val_loss: 3.0267
# Epoch 1515/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0548 - val_loss: 3.0236
# Epoch 1516/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0517 - val_loss: 3.0205
# Epoch 1517/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0487 - val_loss: 3.0174
# Epoch 1518/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0456 - val_loss: 3.0143
# Epoch 1519/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0425 - val_loss: 3.0112
# Epoch 1520/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0394 - val_loss: 3.0081
# Epoch 1521/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0363 - val_loss: 3.0050
# Epoch 1522/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0332 - val_loss: 3.0019
# Epoch 1523/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0301 - val_loss: 2.9988
# Epoch 1524/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0270 - val_loss: 2.9958
# Epoch 1525/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 3.0239 - val_loss: 2.9927
# Epoch 1526/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0208 - val_loss: 2.9896
# Epoch 1527/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0178 - val_loss: 2.9865
# Epoch 1528/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0147 - val_loss: 2.9834
# Epoch 1529/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0116 - val_loss: 2.9803
# Epoch 1530/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0085 - val_loss: 2.9772
# Epoch 1531/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0054 - val_loss: 2.9741
# Epoch 1532/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 3.0023 - val_loss: 2.9711
# Epoch 1533/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9992 - val_loss: 2.9680
# Epoch 1534/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9961 - val_loss: 2.9649
# Epoch 1535/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.9930 - val_loss: 2.9618
# Epoch 1536/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.9900 - val_loss: 2.9587
# Epoch 1537/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 2.
4000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1721 - val_loss: 2.1393
# Epoch 1966/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1701 - val_loss: 2.1373
# Epoch 1967/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1682 - val_loss: 2.1353
# Epoch 1968/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1662 - val_loss: 2.1334
# Epoch 1969/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1642 - val_loss: 2.1314
# Epoch 1970/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1622 - val_loss: 2.1293
# Epoch 1971/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1601 - val_loss: 2.1272
# Epoch 1972/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1580 - val_loss: 2.1252
# Epoch 1973/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1561 - val_loss: 2.1232
# Epoch 1974/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 2.1540 - val_loss: 2.1212
# Epoch 1975/4000
# ...
# Epoch 3843/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3844/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3845/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3846/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3847/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3848/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3849/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3850/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3851/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3852/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3853/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3854/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7114
# Epoch 3855/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3856/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3857/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3858/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3859/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3860/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7114
# Epoch 3861/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3862/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3863/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3864/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3865/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3866/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7114
# Epoch 3867/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3868/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3869/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3870/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3871/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3872/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3873/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3874/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3875/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3876/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3877/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3878/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3879/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3880/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3881/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3882/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3883/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3884/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3885/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3886/4000
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3887/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3888/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3889/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3890/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3891/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3892/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3893/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3894/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3895/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3896/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3897/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3898/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3899/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3900/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3901/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3902/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3903/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3904/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3905/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3906/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3907/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3908/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3909/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3910/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3911/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3912/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3913/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3914/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3915/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3916/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3917/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3918/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3919/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3920/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3921/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3922/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3923/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3924/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3925/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3926/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3927/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3928/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3929/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3930/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3931/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3932/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3933/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3934/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3935/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3936/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3937/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3938/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3939/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3940/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3941/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3942/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3943/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3944/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3945/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3946/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3947/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3948/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3949/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3950/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3951/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3952/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3953/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3954/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3955/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3956/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3957/4000
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3958/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3959/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3960/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3961/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3962/4000
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3963/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3964/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3965/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3966/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3967/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3968/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3969/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3970/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3971/4000
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3972/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3973/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3974/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3975/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3976/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3977/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3978/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3979/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3980/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3981/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3982/4000
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3983/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3984/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3985/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3986/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3987/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3988/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3989/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3990/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3991/4000
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3992/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3993/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3994/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3995/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3996/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3997/4000
# 7/7 [==============================] - 0s 9ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 3998/4000
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5651 - val_loss: 1.7113
# Epoch 3999/4000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5650 - val_loss: 1.7113
# Epoch 4000/4000
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5650 - val_loss: 1.7113

# %%
#plot the loss function ("average error")
fig, ax=plt.subplots()
ax.plot(model_history.history['val_loss'], label='Validation')
ax.plot(model_history.history['loss'], label='Training')
ax.set(ylabel='Average Error', xlabel='Epoch', yscale='log')
plt.legend()

# %% [markdown]
# Once the validation error flattens and start being larger that our training error, the model is overfitting. One can limit tune the number of training epochs in order to avoid overfitting

# %%
#make predictions 
y_pred_neural_net= heurmodel.predict(X_test)
#compute the average error on the test set
print ('average error rate for the RF is {:.4f} subtypes'.format(np.nanmean(abs(y_pred_neural_net-y_test))))
# Out:
# average error rate for the RF is 1.8379 subtypes

# %% [markdown]
# Not very good!
#
# You can improve this by defining your a custom loss function and tuning parameters of the neural net

# %% [markdown]
# # References & Sources

# %% [markdown]
# This notebook uses some material from the LSST-DSFP fellowship program Session 1 shorturl.at/tzMTY , sklearn documentation and astroquery documentation
